# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
# request through the Splash

url = 'https://www.amazon.in/Canon-EOS-200D-II-Digital/product-reviews/B07RJWB548/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

r = requests.get('http://localhost:8050/render.html',params={'url':url, 'wait' :2})

soup = BeautifulSoup(r.text,'html.parser')

print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="a-js a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-touch a-gradients a-transform3d a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition" data-19ax5a9jf="dingo" data-aui-build-date="3.21.9-2022-01-05" lang="en-in"><!-- sp:feature:head-start --><head><script async="" crossorigin="anonymous" src="https://c.amazon-adsystem.com/bao-csm/forensics/a9-tq-forensics.min.js"></script><script async="" crossorigin="anonymous" src="https://m.media-amazon.com/images/G/01/csm/showads.v2.js?adtag=csm&amp;ad_box_"></script><script async="" crossorigin="anonymous" src="https://images-eu.ssl-images-amazon.com/images/I/31YXrY93hfL.js"></script><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# ...

# %%
# I want to extract the   1. Reviews Title   2.Reviews Text    3. Reviews Rating

reviews = soup.find_all('div',{'data-hook':'review'})

review_list = []

try :

    for item in reviews:

        review = {
        'title' : item.find('a',{'data-hook' : 'review-title'}).text.strip(),
        'rating' : float(item.find('i',{'data-hook' : 'review-star-rating'}).text.replace(' out of 5 stars','').strip()),
        'body' : item.find('span',{'data-hook':'review-body'}).text.strip() 
                }

        review_list.append(review)

except:
    pass

# %%
review_list
# Out:
# [{'title': 'Good for overall performance',
#   'rating': 4.0,
#   'body': "As a beginner's camera this is perhaps the best one. A lot can be learned quickly by nevigating the guided Menu. However, this Moonshot is my first snap fron Canon eos 200D Mark II."},
#  {'title': 'Brilliant Digic 8',
#   'rating': 5.0,
#   'body': 'topnotch image processor, (digic8) is perhaps the selling point of this product. Best for beginners, auto-focus improves much more in the live view mode. Image can be cropped without losing the quality. 4k is useless, but other mode gives u eye focus on video shooting.'},
#  {'title': 'Awesome But Price too high',
#   'rating': 5.0,
#   'body': 'Good Camera But Price On Amazon Too High'},
#  {'title': 'COMPANIE REGARDING PRODUCT DELIVERED',
#   'rating': 1.0,
# ...

# %%
# iterating over multiple Pages - Creating Function

review_list_cmplt = []

def get_soup(url):
    
    r = requests.get('http://localhost:8050/render.html',params={'url':url, 'wait' : 2})
    
    soup = BeautifulSoup(r.text, 'html.parser')
    
    return soup


def get_reviews(soup):
    
    reviews = soup.find_all('div',{'data-hook':'review'})

    try :

        for item in reviews:

            review = {
            'title' : item.find('a',{'data-hook' : 'review-title'}).text.strip(),
            'rating' : float(item.find('i',{'data-hook' : 'review-star-rating'}).text.replace(' out of 5 stars','').strip()),
            'body' : item.find('span',{'data-hook':'review-body'}).text.strip() 
                    }

            review_list_cmplt.append(review)

    except:
        pass

# %%
# extracting reviews from multiple pages

for x in range(1,50):
    url =f'https://www.amazon.in/Canon-EOS-200D-II-Digital/product-reviews/B07RJWB548/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber={x}'
    soup = get_soup(url)
    print(f'Getting Page {x}')
    
    get_reviews(soup)
    print(len(review_list_cmplt))
    
    if not soup.find('li',{'class':'a-disabled a-last'}):
        pass
    
    else:
        break
# Out:
# Getting Page 1
# 10
# Getting Page 2
# 20
# Getting Page 3
# 30
# Getting Page 4
# 40
# Getting Page 5
# 50
# Getting Page 6
# 60
# Getting Page 7
# 70
# Getting Page 8
# 80
# Getting Page 9
# 90
# Getting Page 10
# 100
# Getting Page 11
# 110
# Getting Page 12
# 120
# Getting Page 13
# 130
# Getting Page 14
# 140
# Getting Page 15
# 150
# Getting Page 16
# 160
# Getting Page 17
# 170
# Getting Page 18
# 180
# Getting Page 19
# 190
# Getting Page 20
# 200
# Getting Page 21
# 210
# Getting Page 22
# 220
# Getting Page 23
# 230
# Getting Page 24
# 240
# Getting Page 25
# 250
# Getting Page 26
# 260
# Getting Page 27
# 270
# Getting Page 28
# 280
# Getting Page 29
# 290
# Getting Page 30
# 300
# Getting Page 31
# 310
# Getting Page 32
# 320
# Getting Page 33
# 330
# Getting Page 34
# 332

# %%
df = pd.DataFrame(review_list_cmplt)

df.head(20)
# Out:
#                                                 title  rating  \
# 0                        Good for overall performance     4.0
# 1                                   Brilliant Digic 8     5.0
# 2                          Awesome But Price too high     5.0
# 3                COMPANIE REGARDING PRODUCT DELIVERED     1.0
# 4                       Mind blowing product by Canon     5.0
# 5   Perfect entry level camera with 4K video & dua...     5.0
# 6   Fake low quality build camera being sold in India     1.0
# 7   Canon EOS 200D II 24.1MP Digital SLR Camera + ...     2.0
# 8   Super Camera for Beginners, comes with some Pr...     5.0
# 9   Perfect DSLR in this price range. Review after...     5.0
# 10                                   Don't buy online     1.0
# 11       Perfect Camera for Beginners and Enthusiasts     5.0
# 12              Return period over problem start ☺️☺️     2.0
# 13                                          Mast DSLR     5.0
# ...
